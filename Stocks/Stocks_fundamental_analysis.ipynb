# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekparasharr/Applying-Data-Science/blob/main/Stocks/Stocks_fundamental_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install fundamentalanalysis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import fundamentalanalysis as fa

# %%
ticker = "MSFT"
api_key = "saved-in-bw.."

# %%
# Show the available companies
companies = fa.available_companies(api_key)
companies
# Out:
#                                                         name      price  \
# symbol
# 603111.SS     Nanjing Kangni Mechanical & Electrical Co.,Ltd     4.1800
# JPMF                   JPMorgan Managed Futures Strategy ETF    20.8500
# STGZ                       Stargaze Entertainment Group Inc.     0.0315
# NWXQX                   Nationwide Mid Cap Market Index Fund    16.0200
# JRDM.L     JPMorgan ETFs (Ireland) ICAV - Global Emerging...  2008.0000
# ...                                                      ...        ...
# TRUS.JK                       PT Trust Finance Indonesia Tbk   352.0000
# MLTM.TA                                     Malam - Team Ltd  7657.0000
# BKY.L                               Berkeley Energia Limited    15.7500
# 0224.HK                         Pioneer Global Group Limited     0.8000
# 600346.SS                      Hengli Petrochemical Co.,Ltd.    16.3800
#
#                                exchange exchangeShortName   type
# symbol
# ...

# %%
# Collect general company information
profile = fa.profile(ticker, api_key)
profile
# Out:
#                                                                    0
# symbol                                                          MSFT
# price                                                         244.43
# beta                                                        0.933189
# volAvg                                                      30802152
# mktCap                                                 1822096137298
# lastDiv                                                         2.54
# range                                                   213.43-344.3
# changes                                                         2.63
# companyName                                    Microsoft Corporation
# currency                                                         USD
# cik                                                       0000789019
# isin                                                    US5949181045
# cusip                                                      594918104
# ...

# %%
# Collect recent company quotes
quotes = fa.quote(ticker, api_key)
quotes
# Out:
#                                                  0
# symbol                                        MSFT
# name                         Microsoft Corporation
# price                                       244.43
# changesPercentage                           1.0877
# change                                        2.63
# dayLow                                      240.11
# dayHigh                                    245.615
# yearHigh                                     344.3
# yearLow                                     213.43
# marketCap                            1822096137298
# priceAvg50                                239.9264
# priceAvg200                              262.56995
# volume                                    22566734
# avgVolume                                 30802152
# exchange                                    NASDAQ
# open                                        241.69
# previousClose                                241.8
# ...

# %%
# Collect market cap and enterprise value
entreprise_value = fa.enterprise(ticker, api_key)
entreprise_value
# Out:
#                                              2022                  2021  \
# symbol                                       MSFT                  MSFT
# stockPrice                              280.73999            284.910004
# numberOfShares                         7496000000            7547000000
# marketCapitalization         2104426966539.200195  2150215797923.900146
# minusCashAndCashEquivalents           13931000000           14224000000
# addTotalDebt                          61270000000           67775000000
# enterpriseValue              2151765966539.200195  2203766797923.900391
#
#                                       2020                  2019  \
# symbol                                MSFT                  MSFT
# stockPrice                      203.899994            140.350006
# numberOfShares                  7610000000            7673000000
# marketCapitalization         1551678953579  1076905596805.300049
# ...

# %%
# Show recommendations of Analysts
ratings = fa.rating(ticker, api_key)
ratings
# Out:
#            rating  ratingScore ratingRecommendation  ratingDetailsDCFScore  \
# date
# 2022-12-20     S-            5           Strong Buy                      5
# 2022-12-19     S-            5           Strong Buy                      5
# 2022-12-16     S-            5           Strong Buy                      5
# 2022-12-15     S-            5           Strong Buy                      5
# 2022-12-14     S-            5           Strong Buy                      5
#
#            ratingDetailsDCFRecommendation  ratingDetailsROEScore  \
# date
# 2022-12-20                     Strong Buy                      4
# 2022-12-19                     Strong Buy                      4
# 2022-12-16                     Strong Buy                      4
# 2022-12-15                     Strong Buy                      4
# 2022-12-14                     Strong Buy                      4
#
#            ratingDetailsROERecommendation  ratingDetailsROAScore  \
# date
# ...

# %%
# Obtain DCFs over time
dcf_annually = fa.discounted_cash_flow(ticker, api_key, period="annual")
dcf_annually
# Out:
#                    2022        2021        2020        2019        2018  \
# date         2022-12-21  2021-06-30  2020-06-30  2019-06-30  2018-06-30
# Stock Price      244.43  284.910004  203.899994  140.350006  105.370003
# DCF          246.277613  286.466649  205.683962  141.830001  106.921431
#
#                    2017        2016        2015        2014        2013  ...  \
# date         2017-06-30  2016-06-30  2015-06-30  2014-06-30  2013-06-30  ...
# Stock Price   73.040001       56.68   46.880001   43.580002       31.85  ...
# DCF           74.029286   57.501451   47.564237   44.624585   32.304209  ...
#
#                    1995        1994        1993        1992        1991  \
# date         1995-06-30  1994-06-30  1993-06-30  1992-06-30  1991-06-30
# Stock Price    5.789063     3.21875      2.3125    2.285156    1.515625
# DCF            5.984637    3.370082    2.418796    2.373629    1.562899
#
#                    1990        1989        1988        1987        1986
# ...

# %%
# Collect the Income Statements
income_statement_annually = fa.income_statement(ticker, api_key, period="annual")
income_statement_annually
# Out:
#                                                                                       2022  \
# reportedCurrency                                                                       USD
# cik                                                                             0000789019
# fillingDate                                                                     2022-07-28
# acceptedDate                                                           2022-07-28 16:06:19
# calendarYear                                                                          2022
# period                                                                                  FY
# revenue                                                                       198270000000
# costOfRevenue                                                                  62650000000
# grossProfit                                                                   135620000000
# ...

# %%
# Collect the Cash Flow Statements
cash_flow_statement_annually = fa.cash_flow_statement(ticker, api_key, period="annual")
cash_flow_statement_annually
# Out:
#                                                                                        2022  \
# reportedCurrency                                                                        USD
# cik                                                                              0000789019
# fillingDate                                                                      2022-07-28
# acceptedDate                                                            2022-07-28 16:06:19
# calendarYear                                                                           2022
# period                                                                                   FY
# netIncome                                                                       72738000000
# depreciationAndAmortization                                                     14460000000
# deferredIncomeTax                                                               -5702000000
# ...

# %%
# Show Key Metrics
key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")
key_metrics_annually
# Out:
#                                                         2022  \
# period                                                    FY
# revenuePerShare                                    26.450107
# netIncomePerShare                                   9.703575
# operatingCashFlowPerShare                          11.877668
# freeCashFlowPerShare                                8.691169
# cashPerShare                                       13.973986
# bookValuePerShare                                  22.217449
# tangibleBookValuePerShare                          11.702241
# shareholdersEquityPerShare                         22.217449
# interestDebtPerShare                                8.448906
# marketCap                               2104426966539.200195
# enterpriseValue                         2151765966539.200195
# peRatio                                            28.931603
# priceToSalesRatio                                  10.613945
# ...

# %%
# Show a large set of in-depth ratios
financial_ratios_annually = fa.financial_ratios(ticker, api_key, period="annual")
financial_ratios_annually
# Out:
#                                           2022        2021        2020  \
# period                                      FY          FY          FY
# currentRatio                          1.784607    2.079994    2.515765
# quickRatio                            1.567174    1.899196     2.33077
# cashRatio                             0.146516    0.160439    0.187747
# daysOfSalesOutstanding               81.481137   82.609675   81.697829
# daysOfInventoryOutstanding           21.800958   18.420509    15.01096
# operatingCycle                      103.282095  101.030183   96.708789
# daysOfPayablesOutstanding           110.694334  105.959852   99.254525
# cashConversionCycle                  -7.412239   -4.929669   -2.545736
# grossProfitMargin                     0.684017    0.689258     0.67781
# operatingProfitMargin                 0.420553    0.415949    0.370304
# pretaxProfitMargin                    0.422232    0.423005    0.370842
# ...

# %%
# Show the growth of the company
growth_annually = fa.financial_statement_growth(ticker, api_key, period="annual")
growth_annually
# Out:
#                                             2022      2021      2020  \
# period                                        FY        FY        FY
# revenueGrowth                           0.179561  0.175317  0.136456
# grossProfitGrowth                       0.170591  0.195168  0.168859
# ebitgrowth                              0.192617  0.320191   0.23278
# operatingIncomeGrowth                   0.192617  0.320191   0.23278
# netIncomeGrowth                         0.187152  0.383686  0.128466
# epsgrowth                               0.194581  0.395189  0.138943
# epsdilutedGrowth                        0.198758  0.397569   0.13834
# weightedAverageSharesGrowth            -0.006758 -0.008279 -0.008211
# weightedAverageSharesDilutedGrowth     -0.008938 -0.009762 -0.009029
# dividendsperShareGrowth                 0.105162  0.100543  0.105084
# operatingCashFlowGrowth                 0.160216  0.264771   0.16269
# freeCashFlowGrowth                      0.160929  0.240615  0.182279
# ...

# %%
# Download general stock data
stock_data = fa.stock_data(ticker, period="ytd", interval="1d")
stock_data
# Out:
#               volume         low        high        open       close  \
# 2022-01-03  28865100  329.779999  338.000000  335.350006  334.750000
# 2022-01-04  32674300  326.119995  335.200012  334.829987  329.010010
# 2022-01-05  40054300  315.980011  326.070007  325.859985  316.380005
# 2022-01-06  39646100  311.489990  318.700012  313.149994  313.880005
# 2022-01-07  32720000  310.089996  316.500000  314.149994  314.040009
# ...              ...         ...         ...         ...         ...
# 2022-12-15  35560400  247.339996  254.199997  253.720001  249.009995
# 2022-12-16  86088100  243.509995  249.839996  248.550003  244.690002
# 2022-12-19  29696400  238.710007  245.210007  244.860001  240.449997
# 2022-12-20  25150800  238.419998  242.910004  239.399994  241.800003
# 2022-12-21  22566734  240.110001  245.615005  241.690002  244.429993
#
#               adjclose
# 2022-01-03  331.642426
# 2022-01-04  325.955750
# 2022-01-05  313.442993
# 2022-01-06  310.966187
# ...

# %%
# Download detailed stock data
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2000-01-01", end="2020-01-01")
stock_data_detailed
# Out:
#                   open        high         low       close    adjClose  \
# 2019-12-31  156.770004  157.770004  156.449997  157.699997  153.313171
# 2019-12-30  158.990005  159.020004  156.729996  157.589996  153.206238
# 2019-12-27  159.449997  159.550003  158.220001  158.960007  154.538147
# 2019-12-26  157.559998  158.729996  157.399994  158.669998  154.256195
# 2019-12-24  157.479996  157.710007  157.119995  157.380005  153.002091
# ...                ...         ...         ...         ...         ...
# 2000-01-07     54.3125      56.125    53.65625    55.71875   34.849892
# 2000-01-06    56.09375     56.9375     54.1875        55.0   34.400356
# 2000-01-05     55.5625     58.1875     54.6875    56.90625    35.59264
# 2000-01-04    56.78125     58.5625      56.125     56.3125   35.221279
# 2000-01-03     58.6875     59.3125        56.0    58.28125   36.452644
#
#                 volume unadjustedVolume    change changePercent       vwap  \
# ...

# %%
# Download dividend history
dividends = fa.stock_dividend(ticker, api_key, begin="2000-01-01", end="2020-01-01")
dividends
# Out:
#                       label adjDividend dividend  recordDate paymentDate  \
# 2019-11-20  November 20, 19        0.51     0.51  2019-11-21  2019-12-12
# 2019-08-14    August 14, 19        0.46     0.46  2019-08-15  2019-09-12
# 2019-05-15       May 15, 19        0.46     0.46  2019-05-16  2019-06-13
# 2019-02-20  February 20, 19        0.46     0.46  2019-02-21  2019-03-14
# 2018-11-14  November 14, 18        0.46     0.46  2018-11-15  2018-12-13
# ...                     ...         ...      ...         ...         ...
# 2005-02-15  February 15, 05        0.08     0.08  2005-02-17  2005-03-10
# 2004-11-15  November 15, 04        3.08     3.08  2004-11-17  2004-12-02
# 2004-08-23    August 23, 04        0.08     0.08  2004-08-25  2004-09-14
# 2003-10-15   October 15, 03        0.16     0.16  2003-10-17  2003-11-07
# 2003-02-19  February 19, 03        0.08     0.08  2003-02-21  2003-03-07
#
#            declarationDate
# 2019-11-20      2019-09-18
# 2019-08-14      2019-06-12
# ...
